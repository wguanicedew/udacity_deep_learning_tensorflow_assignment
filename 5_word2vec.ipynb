# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['anarchism', 'as', 'originated', 'a', 'as', 'term', 'a', 'of']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['originated', 'anarchism', 'a', 'term', 'originated', 'term', 'of', 'as']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.213001
# Nearest to there: azzam, algorithms, durations, nepotism, bank, livery, sprengel, aptitude,
# Nearest to d: slider, ifrcs, remedies, aa, courageous, nazionale, newspaper, lateran,
# Nearest to have: vav, absent, buyout, montagu, ortelius, gap, quicker, cheering,
# Nearest to american: aldrin, paperwork, impresario, anaesthesia, quizzes, foal, edessa, malls,
# Nearest to at: douglass, learner, auctioned, reformers, francorum, adret, casing, ostara,
# Nearest to some: thabit, cheesemaking, lactation, ryukyu, philosophie, clemency, shelling, burnley,
# Nearest to were: isn, lara, misunderstandings, vagus, separatist, ghost, gathers, louie,
# Nearest to a: straps, ecclesia, preston, ima, inland, emanations, raeder, meats,
# Nearest to to: essential, insecurity, buckland, auctioned, delegates, wholesale, woodson, threatening,
# Nearest to system: paraphrase, kibaki, agonist, mathematical, shrinks, tisdall, warren, racer,
# Nearest to all: classification, merging, everyman, sade, ideogram, calamine, active, satchmo,
# Nearest to and: ium, salvadoran, jackass, solicitation, il, differentiating, raimi, grandson,
# Nearest to one: elisa, abilities, deposition, belgium, asean, emotional, mythical, achill,
# Nearest to people: menai, sci, jorge, zahn, chlorophyll, achieves, endlessly, baccalaureate,
# Nearest to with: porn, blooming, runic, falkland, coronary, passport, marine, scrape,
# Nearest to its: mountainous, rojcewicz, injecting, sinai, variables, elmendorf, sind, aggressiveness,
# Average loss at step 2000: 4.364452
# Average loss at step 4000: 3.868643
# Average loss at step 6000: 3.788350
# Average loss at step 8000: 3.690364
# Average loss at step 10000: 3.614552
# Nearest to there: it, they, repellent, not, he, also, livery, vaginal,
# Nearest to d: b, nazionale, ihs, citizenship, bluescreen, courageous, ifrcs, bahama,
# Nearest to have: had, has, be, are, absent, were, vav, montagu,
# Nearest to american: crescent, aldrin, and, lingered, nsh, tripod, anaesthesia, british,
# Nearest to at: on, in, impregnated, from, by, of, when, auctioned,
# Nearest to some: many, other, exception, lactation, tetrahedron, range, observances, engelbert,
# Nearest to were: are, was, lara, have, wouldn, filkers, gathers, progressing,
# Nearest to a: the, cav, ohrid, incompatible, invaluable, metropolitan, sleeves, fiat,
# Nearest to to: would, vsl, can, murron, skewed, dogg, cannot, dissociation,
# Nearest to system: paraphrase, kibaki, sixths, warren, worm, agonist, mathematical, block,
# Nearest to all: nic, judicial, slack, innocents, melanchthon, classification, camelids, plea,
# Nearest to and: or, of, but, in, he, who, s, uncontrollably,
# Nearest to one: two, three, eight, seven, four, six, corroborating, acids,
# Nearest to people: clearly, sci, organists, jorge, abundant, sketched, protector, endlessly,
# Nearest to with: for, in, by, between, on, sinauer, depopulated, kernewek,
# Nearest to its: the, his, their, injecting, firefly, variables, vowed, elmendorf,
# Average loss at step 12000: 3.605457
# Average loss at step 14000: 3.571297
# Average loss at step 16000: 3.409368
# Average loss at step 18000: 3.461092
# Average loss at step 20000: 3.544457
# Nearest to there: it, they, he, which, repellent, pedro, not, vara,
# Nearest to d: b, vaikundar, archibald, du, wardens, nanette, humanist, medalist,
# Nearest to have: had, has, be, were, are, harpers, produce, do,
# Nearest to american: british, nsh, national, russian, stargate, german, strives, crescent,
# Nearest to at: in, on, from, during, glagolitic, allege, kashmir, impregnated,
# Nearest to some: many, these, other, their, several, stained, all, this,
# Nearest to were: are, was, have, had, been, is, dishonest, by,
# Nearest to a: cav, elphinstone, parnell, any, gelfand, the, zak, forseti,
# Nearest to to: will, would, viewing, cannot, can, not, may, should,
# Nearest to system: warren, worm, paraphrase, mathematical, sixths, enormously, bancroft, kibaki,
# Nearest to all: many, several, nic, slack, innocents, some, camelids, amt,
# Nearest to and: or, but, whose, in, which, while, entries, myanmar,
# Nearest to one: four, two, seven, three, eight, six, five, nine,
# Nearest to people: clearly, sketched, jorge, protector, rationalist, endlessly, sci, sprang,
# Nearest to with: in, between, for, by, ip, depopulated, nativist, hotspots,
# Nearest to its: their, his, the, several, skipped, orioles, firefly, her,
# Average loss at step 22000: 3.504374
# Average loss at step 24000: 3.489031
# Average loss at step 26000: 3.480858
# Average loss at step 28000: 3.481514
# Average loss at step 30000: 3.500958
# Nearest to there: they, it, he, which, this, repellent, not, often,
# Nearest to d: b, nanette, anthology, archibald, humanist, rgya, ramone, medalist,
# Nearest to have: had, has, are, were, be, produce, having, include,
# Nearest to american: british, scottish, national, ecologist, french, german, english, captors,
# Nearest to at: in, during, on, impregnated, when, after, capsules, around,
# Nearest to some: many, these, several, their, most, any, other, all,
# Nearest to were: are, was, have, had, been, those, be, is,
# Nearest to a: any, the, cav, mencius, straps, nss, metropolitan, this,
# Nearest to to: would, cannot, can, should, will, determinate, in, not,
# Nearest to system: warren, enormously, worm, systems, paraphrase, dupuis, mathematical, block,
# Nearest to all: many, several, various, slack, some, innocents, these, altaic,
# Nearest to and: but, or, however, giga, while, in, american, izz,
# Nearest to one: two, seven, four, six, five, eight, three, nine,
# Nearest to people: protector, endlessly, sketched, baserunners, clearly, degrees, aubier, casualties,
# Nearest to with: between, in, when, for, among, by, like, sinauer,
# Nearest to its: their, his, the, orioles, her, several, ina, obstruction,
# Average loss at step 32000: 3.502982
# Average loss at step 34000: 3.499739
# Average loss at step 36000: 3.454992
# Average loss at step 38000: 3.307222
# Average loss at step 40000: 3.424555
# Nearest to there: they, it, he, now, still, often, which, repellent,
# Nearest to d: b, anthology, UNK, archibald, conventionally, nanette, du, l,
# Nearest to have: had, has, were, are, be, produce, having, include,
# Nearest to american: british, german, scottish, russian, australian, national, english, french,
# Nearest to at: during, on, reached, in, bayard, around, matisse, instant,
# Nearest to some: many, several, these, any, their, other, stained, most,
# Nearest to were: are, have, was, been, had, those, be, while,
# Nearest to a: the, any, another, straps, indelible, elphinstone, parnell, slain,
# Nearest to to: will, in, cannot, can, trioxide, vertically, hakama, promulgated,
# Nearest to system: systems, warren, mathematical, enormously, latinate, paraphrase, block, dupuis,
# Nearest to all: many, several, these, slack, deposition, various, every, any,
# Nearest to and: or, but, in, like, however, while, amistad, cira,
# Nearest to one: seven, two, eight, six, five, four, three, nine,
# Nearest to people: children, species, protector, baserunners, tandy, men, publishers, endlessly,
# Nearest to with: falkland, between, pm, in, isolates, makes, by, depopulated,
# Nearest to its: their, his, the, her, reconstruction, ode, several, adhesion,
# Average loss at step 42000: 3.438814
# Average loss at step 44000: 3.452678
# Average loss at step 46000: 3.449136
# Average loss at step 48000: 3.350564
# Average loss at step 50000: 3.380932
# Nearest to there: they, it, he, repellent, she, who, now, these,
# Nearest to d: b, archibald, m, anthology, p, j, r, g,
# Nearest to have: had, has, were, be, are, having, produce, refer,
# Nearest to american: english, russian, british, scottish, australian, ethnology, german, ecologist,
# Nearest to at: during, eb, in, reached, on, ibn, from, around,
# Nearest to some: many, several, these, any, various, their, stained, those,
# Nearest to were: are, have, was, had, be, those, been, predicts,
# Nearest to a: another, the, elphinstone, cali, any, straps, sleeves, incompatible,
# Nearest to to: cuttlefish, could, will, may, would, cannot, icebergs, might,
# Nearest to system: systems, warren, paraphrase, enormously, latinate, commutes, block, ovary,
# Nearest to all: every, any, various, many, these, some, each, several,
# Nearest to and: or, but, including, while, however, of, s, although,
# Nearest to one: two, four, eight, six, seven, three, five, nine,
# Nearest to people: children, men, endlessly, degrees, baserunners, protector, casualties, wives,
# Nearest to with: between, falkland, quintet, alpinus, themis, notebooks, makes, pm,
# Nearest to its: their, his, the, her, ina, reconstruction, ode, motorcyclist,
# Average loss at step 52000: 3.437951
# Average loss at step 54000: 3.428361
# Average loss at step 56000: 3.439919
# Average loss at step 58000: 3.400504
# Average loss at step 60000: 3.392635
# Nearest to there: they, it, this, now, he, still, she, we,
# Nearest to d: b, archibald, l, m, elektra, anthology, p, j,
# Nearest to have: had, has, were, are, having, produce, refer, provoked,
# Nearest to american: british, australian, english, russian, scottish, ecologist, gardner, german,
# Nearest to at: during, reached, in, on, proactive, allege, agrarian, colonnade,
# Nearest to some: many, several, these, any, this, their, various, stained,
# Nearest to were: are, have, was, been, had, those, including, be,
# Nearest to a: any, the, another, every, invaluable, applicative, nss, elphinstone,
# Nearest to to: determinate, for, cannot, not, would, rapcore, viewing, annealing,
# Nearest to system: systems, block, mathematical, nhk, enormously, means, warren, latinate,
# Nearest to all: various, many, every, any, some, each, both, altaic,
# Nearest to and: or, but, although, polonia, than, including, in, however,
# Nearest to one: two, six, eight, seven, four, five, nine, three,
# Nearest to people: children, men, writers, scholars, baserunners, songs, species, those,
# Nearest to with: between, depopulated, falkland, by, when, in, quintet, branko,
# Nearest to its: their, his, the, her, adhesion, obstruction, some, skipped,
# Average loss at step 62000: 3.246872
# Average loss at step 64000: 3.253307
# Average loss at step 66000: 3.402825
# Average loss at step 68000: 3.397685
# Average loss at step 70000: 3.360920
# Nearest to there: they, it, he, we, often, generally, still, she,
# Nearest to d: b, archibald, elektra, j, l, anthology, r, du,
# Nearest to have: had, has, were, are, having, produce, be, tend,
# Nearest to american: british, english, australian, scottish, ecologist, airstream, russian, african,
# Nearest to at: during, in, after, on, reached, near, colonnade, walled,
# Nearest to some: many, several, these, all, various, most, their, any,
# Nearest to were: are, was, have, had, be, been, yardage, those,
# Nearest to a: the, another, any, gelfand, straps, elphinstone, preston, cav,
# Nearest to to: can, cannot, will, would, should, integrating, determinate, sans,
# Nearest to system: systems, vivisection, block, process, urbanisation, foxes, rpp, engagements,
# Nearest to all: many, every, various, any, some, several, each, those,
# Nearest to and: or, while, but, like, which, of, including, arr,
# Nearest to one: two, seven, six, four, eight, five, three, nine,
# Nearest to people: children, men, writers, women, those, scholars, baserunners, members,
# Nearest to with: between, falkland, makes, bowls, when, origami, wilbur, pm,
# Nearest to its: their, his, the, her, several, adhesion, your, ode,
# Average loss at step 72000: 3.378325
# Average loss at step 74000: 3.348395
# Average loss at step 76000: 3.318364
# Average loss at step 78000: 3.350347
# Average loss at step 80000: 3.379020
# Nearest to there: it, they, he, still, we, often, now, generally,
# Nearest to d: b, elektra, l, f, du, anthology, j, m,
# Nearest to have: had, has, are, be, were, refer, having, produce,
# Nearest to american: british, english, russian, australian, german, scottish, canadian, ecologist,
# Nearest to at: during, in, around, after, on, allege, before, reached,
# Nearest to some: many, several, most, these, any, various, both, all,
# Nearest to were: are, had, was, have, those, been, be, homomorphisms,
# Nearest to a: another, the, elphinstone, preston, straps, applicative, cali, every,
# Nearest to to: cannot, should, would, determinate, will, icebergs, can, metamorphoses,
# Nearest to system: systems, process, vivisection, foxes, theory, restart, methods, rpp,
# Nearest to all: every, both, many, various, several, any, each, some,
# Nearest to and: or, but, including, while, although, polonia, than, impresario,
# Nearest to one: seven, two, six, eight, three, five, four, vegetarians,
# Nearest to people: men, children, writers, women, baserunners, students, person, meow,
# Nearest to with: between, falkland, expressionist, when, including, koi, bowls, among,
# Nearest to its: their, his, her, the, your, adhesion, reconstruction, commercial,
# Average loss at step 82000: 3.407609
# Average loss at step 84000: 3.413614
# Average loss at step 86000: 3.389956
# Average loss at step 88000: 3.355146
# Average loss at step 90000: 3.363804
# Nearest to there: they, it, he, we, still, she, sometimes, generally,
# Nearest to d: b, elektra, inspections, j, unsigned, l, letsie, archibald,
# Nearest to have: had, has, be, were, having, are, refer, tend,
# Nearest to american: british, russian, english, australian, french, ecologist, german, canadian,
# Nearest to at: during, near, licks, impregnated, around, reached, after, bayard,
# Nearest to some: many, several, these, any, most, all, this, stained,
# Nearest to were: are, had, was, have, those, while, these, homomorphisms,
# Nearest to a: another, any, straps, lauren, sliced, elphinstone, every, the,
# Nearest to to: would, will, should, integrating, cannot, must, hermaphroditus, surveyed,
# Nearest to system: systems, process, foxes, theory, oppressive, devices, turnaround, concept,
# Nearest to all: both, every, many, several, various, some, each, any,
# Nearest to and: or, but, while, including, through, motorcycle, imagines, arr,
# Nearest to one: seven, two, four, six, eight, five, three, nine,
# Nearest to people: children, men, writers, women, students, person, casualties, jews,
# Nearest to with: between, quintet, by, in, refitted, falkland, bowls, notebooks,
# Nearest to its: their, his, the, her, your, adhesion, whose, ode,
# Average loss at step 92000: 3.398948
# Average loss at step 94000: 3.257952
# Average loss at step 96000: 3.361469
# Average loss at step 98000: 3.243324
# Average loss at step 100000: 3.354439
# Nearest to there: they, it, he, now, we, still, often, generally,
# Nearest to d: b, j, elektra, morgan, convened, calvinists, archibald, giscard,
# Nearest to have: had, has, having, be, are, tend, refer, were,
# Nearest to american: british, russian, australian, french, italian, canadian, settling, english,
# Nearest to at: during, in, after, on, reached, from, under, floated,
# Nearest to some: many, several, these, any, various, all, certain, most,
# Nearest to were: are, was, have, those, had, these, although, homomorphisms,
# Nearest to a: another, the, any, elphinstone, straps, mencius, maui, every,
# Nearest to to: should, could, can, will, must, would, cannot, hakama,
# Nearest to system: systems, process, technology, devices, programmer, networks, turnaround, theory,
# Nearest to all: several, every, many, any, both, these, various, some,
# Nearest to and: but, or, like, while, however, although, when, arr,
# Nearest to one: two, four, six, seven, five, eight, nine, three,
# Nearest to people: children, men, writers, jews, women, students, them, scholars,
# Nearest to with: between, falkland, by, when, origami, yourself, wilbur, denaturation,
# Nearest to its: their, his, the, your, her, adhesion, several, eisenman,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %%
data_index = 0

def generate_batch(batch_size, bag_window):
  global data_index
  span = 2 * bag_window + 1 # [ bag_window target bag_window ]
  batch = np.ndarray(shape=(batch_size, span - 1), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)  
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size):
    # just for testing
    buffer_list = list(buffer)
    labels[i, 0] = buffer_list.pop(bag_window)
    batch[i] = buffer_list
    # iterate to the next buffer
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:16]])

for bag_window in [1, 2]:
  data_index = 0
  batch, labels = generate_batch(batch_size=4, bag_window=bag_window)
  print('\nwith bag_window = %d:' % (bag_window))  
  print('    batch:', [[reverse_dictionary[w] for w in bi] for bi in batch])  
  print('    labels:', [reverse_dictionary[li] for li in labels.reshape(4)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the']
#
# with bag_window = 1:
#     batch: [['anarchism', 'as'], ['originated', 'a'], ['as', 'term'], ['a', 'of']]
#     labels: ['originated', 'as', 'a', 'term']
#
# with bag_window = 2:
#     batch: [['anarchism', 'originated', 'a', 'term'], ['originated', 'as', 'term', 'of'], ['as', 'a', 'of', 'abuse'], ['a', 'term', 'abuse', 'first']]
#     labels: ['as', 'a', 'term', 'of']

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
# skip_window = 1 # How many words to consider left and right.
# num_skips = 2 # How many times to reuse an input to generate a label.
bag_window = 2
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size, bag_window * 2])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=tf.reduce_sum(embed, 1),
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(batch_size, bag_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.236688
# Nearest to can: luang, wishing, fruitarians, hardliners, mayflower, carriage, lactic, deep,
# Nearest to its: boast, blur, presently, hellenes, coerce, franklin, telegraphy, professorship,
# Nearest to eight: uneconomic, framing, gia, rowers, bsa, avian, flirty, throttle,
# Nearest to time: disuse, indistinguishable, want, affiliation, apollonius, falk, rightmost, wielding,
# Nearest to if: mackie, lowers, defunct, authoring, seng, ip, peasant, mention,
# Nearest to when: dramatists, bandai, philibert, jeju, buckingham, membrane, desalination, ragnar,
# Nearest to on: supplies, soundly, blatantly, fournier, kidding, industrialist, gary, lineman,
# Nearest to while: penguin, disorders, rde, madero, knocks, veil, copylefted, zulus,
# Nearest to state: ams, fulda, lymphoid, midwives, schmitz, gratitude, aoc, dad,
# Nearest to of: clinics, dov, senegalese, craps, kl, haines, wallis, optimistic,
# Nearest to with: petrie, forms, reducible, stevenage, incomparable, infra, clausius, dab,
# Nearest to who: cleansed, discoveries, princip, lately, austrians, negroponte, airtight, pergamon,
# Nearest to not: ech, gibson, tera, connotes, ebbinghaus, apprehended, vizier, dass,
# Nearest to by: pliocene, woodside, estimates, ogden, rationalistic, remorse, chamorro, oneself,
# Nearest to other: starbucks, pompey, aurora, iala, ytterbium, sabha, eigenvectors, unrwa,
# Nearest to states: vitoria, tumour, activator, because, package, english, reciprocated, guarantee,
# Average loss at step 2000: 4.602443
# Average loss at step 4000: 3.938626
# Average loss at step 6000: 3.724925
# Average loss at step 8000: 3.539222
# Average loss at step 10000: 3.487492
# Nearest to can: may, will, could, would, should, might, must, to,
# Nearest to its: their, his, the, seaports, her, rhymed, fora, postcolonial,
# Nearest to eight: nine, six, seven, five, four, zero, three, regum,
# Nearest to time: year, beginning, end, marne, wielding, cretinism, pours, preparations,
# Nearest to if: when, katzenjammer, however, sterilization, bosses, rivaling, against, insurmountable,
# Nearest to when: if, imprison, stimulate, hagi, heme, journey, unvoiced, laconia,
# Nearest to on: in, through, milder, into, blatantly, metellus, bizarre, solitaire,
# Nearest to while: amhr, iarc, preterist, bafta, hoyle, dubbed, offers, hamito,
# Nearest to state: metadata, concatenation, invoke, libyan, formulations, ams, episodic, libration,
# Nearest to of: for, amputee, otomo, deprive, shapes, gliding, correspondingly, franchise,
# Nearest to with: refutable, and, caribou, cryptanalyst, unbreakable, contended, exmouth, jungian,
# Nearest to who: that, she, ketubah, he, hominy, stm, cookies, boulders,
# Nearest to not: cyclopedia, dass, binaries, addicts, hadrons, dad, theropod, midair,
# Nearest to by: pulse, raided, donato, resumed, have, telecommunications, for, writeups,
# Nearest to other: various, balmoral, many, these, stationary, concerns, exclaimed, moors,
# Nearest to states: kingdom, bengalis, diners, nations, escrow, underbelly, vitoria, immature,
# Average loss at step 12000: 3.485447
# Average loss at step 14000: 3.438058
# Average loss at step 16000: 3.434806
# Average loss at step 18000: 3.405424
# Average loss at step 20000: 3.220264
# Nearest to can: may, will, could, would, must, might, should, cannot,
# Nearest to its: their, his, her, the, rhymed, platonist, movers, infinitum,
# Nearest to eight: nine, seven, five, six, zero, four, three, sessions,
# Nearest to time: end, least, marne, period, identity, barat, stadium, year,
# Nearest to if: where, when, however, though, glidrose, unleashed, although, laconia,
# Nearest to when: if, where, while, before, during, levies, heme, emissary,
# Nearest to on: upon, about, in, through, starvation, metellus, against, milder,
# Nearest to while: and, but, when, after, however, hasty, like, including,
# Nearest to state: government, episodic, alloy, epitomized, npr, eberhard, valve, hurl,
# Nearest to of: amputee, harrisburg, tagging, negate, in, bardeen, for, dormitories,
# Nearest to with: between, tuba, caribou, contended, laborious, containing, animated, have,
# Nearest to who: which, she, he, ketubah, brainwashing, executed, kleene, berenson,
# Nearest to not: cyclopedia, so, still, wouldn, lingual, belle, often, now,
# Nearest to by: russians, through, bafta, treviso, warranties, singhasari, telecommunications, worden,
# Nearest to other: various, both, different, rather, more, those, these, including,
# Nearest to states: kingdom, nations, tuff, yorkist, newport, unwind, escrow, mysterious,
# Average loss at step 22000: 3.352628
# Average loss at step 24000: 3.293704
# Average loss at step 26000: 3.254978
# Average loss at step 28000: 3.281187
# Average loss at step 30000: 3.220401
# Nearest to can: could, may, must, would, should, will, might, cannot,
# Nearest to its: their, his, rhymed, the, her, yearwood, hydrochloride, our,
# Nearest to eight: nine, six, seven, four, zero, five, three, two,
# Nearest to time: least, end, microcode, period, mudslides, year, epithets, target,
# Nearest to if: when, though, where, because, pdp, however, recorders, although,
# Nearest to when: if, because, where, after, before, unvoiced, what, never,
# Nearest to on: upon, in, through, about, frankie, under, fasces, milder,
# Nearest to while: and, including, however, through, among, thereabouts, after, although,
# Nearest to state: government, seated, hurl, inge, appreciably, moran, pekah, apokryphen,
# Nearest to of: in, during, discernable, otomo, following, before, including, wimp,
# Nearest to with: between, tuba, terminus, exmouth, heartbreak, contended, gave, unbreakable,
# Nearest to who: berenson, which, falconiformes, by, he, cookies, clark, kelsey,
# Nearest to not: cyclopedia, still, now, wouldn, never, belle, megaliths, what,
# Nearest to by: who, against, kip, through, omar, when, olivine, originally,
# Nearest to other: various, different, both, those, many, alleles, these, hasidic,
# Nearest to states: kingdom, nations, coordinating, measuring, ferrer, newport, suburbs, yorkist,
# Average loss at step 32000: 3.019892
# Average loss at step 34000: 3.198498
# Average loss at step 36000: 3.197032
# Average loss at step 38000: 3.157824
# Average loss at step 40000: 3.162450
# Nearest to can: could, may, will, should, would, must, might, cannot,
# Nearest to its: their, his, the, her, your, rhymed, our, platonist,
# Nearest to eight: seven, six, five, nine, four, zero, three, soi,
# Nearest to time: least, period, thing, shires, beginning, stadium, looking, age,
# Nearest to if: though, where, when, since, then, signaling, larva, must,
# Nearest to when: after, where, by, because, before, if, during, making,
# Nearest to on: upon, through, at, across, in, about, after, against,
# Nearest to while: although, among, but, and, however, after, picirilli, though,
# Nearest to state: dragster, airplane, annexes, counselors, government, mens, antichrist, choreographer,
# Nearest to of: almohades, unchanging, within, during, otomo, amputee, discernable, for,
# Nearest to with: between, against, terminus, when, tuba, making, within, by,
# Nearest to who: washtenaw, whose, omar, clark, brainwashing, alem, petrel, executed,
# Nearest to not: still, now, never, cyclopedia, wouldn, theropod, futurist, intracranial,
# Nearest to by: when, from, gutrune, martens, megabyte, sds, with, microbe,
# Nearest to other: various, different, these, fragrant, others, some, rather, roms,
# Nearest to states: kingdom, nations, coordinating, yorkist, measuring, newport, merciful, metabolized,
# Average loss at step 42000: 3.203585
# Average loss at step 44000: 3.145620
# Average loss at step 46000: 3.145219
# Average loss at step 48000: 3.057037
# Average loss at step 50000: 3.067231
# Nearest to can: could, may, must, would, might, will, cannot, should,
# Nearest to its: their, the, his, our, her, your, rhymed, movers,
# Nearest to eight: nine, seven, six, zero, five, four, three, two,
# Nearest to time: point, times, thing, looking, least, shires, night, period,
# Nearest to if: when, where, though, therefore, descendent, because, mujahedeen, surpass,
# Nearest to when: if, because, while, although, before, where, after, though,
# Nearest to on: upon, in, about, under, around, bizarre, fasces, smashing,
# Nearest to while: although, among, when, and, because, where, though, but,
# Nearest to state: city, government, dragster, inge, observant, annexes, decentralized, assembled,
# Nearest to of: amputee, almohades, despite, including, otomo, jimi, maintainer, mua,
# Nearest to with: between, heartbreak, diaeresis, exmouth, frey, selves, confederations, terminus,
# Nearest to who: washtenaw, berenson, he, sorties, which, she, kodansha, alem,
# Nearest to not: never, still, indeed, now, better, conciliatory, nor, kelp,
# Nearest to by: pelvic, newly, through, olivine, utterances, without, under, thus,
# Nearest to other: various, others, these, abram, fdr, hae, smaller, older,
# Nearest to states: kingdom, nations, retired, coordinating, tenants, yorkist, unwind, tomorrow,
# Average loss at step 52000: 3.097904
# Average loss at step 54000: 3.099070
# Average loss at step 56000: 2.912299
# Average loss at step 58000: 3.017461
# Average loss at step 60000: 3.048512
# Nearest to can: could, may, should, might, must, will, cannot, would,
# Nearest to its: their, his, her, our, the, platonist, your, rhymed,
# Nearest to eight: nine, seven, six, five, four, zero, three, two,
# Nearest to time: period, least, thing, times, point, year, age, night,
# Nearest to if: when, where, though, ll, since, because, while, mailbox,
# Nearest to when: if, before, where, though, after, because, while, during,
# Nearest to on: upon, through, under, about, augsburg, around, fogo, towards,
# Nearest to while: although, and, when, though, however, where, but, because,
# Nearest to state: government, states, protoscience, city, karol, ascetics, annexes, macaulay,
# Nearest to of: discernable, amputee, almohades, including, in, subliminal, detachable, glorioso,
# Nearest to with: between, including, tuba, against, heartbreak, among, selves, karma,
# Nearest to who: berenson, whose, microeconomics, attenborough, he, sorties, workman, kodansha,
# Nearest to not: never, indeed, still, now, condemned, conciliatory, battlecruisers, crucifix,
# Nearest to by: under, toward, from, against, gutrune, thus, crocodile, landscaping,
# Nearest to other: various, these, others, both, those, their, older, different,
# Nearest to states: kingdom, nations, countries, griswold, state, suburbs, accelerators, crazy,
# Average loss at step 62000: 3.008126
# Average loss at step 64000: 2.919519
# Average loss at step 66000: 2.929681
# Average loss at step 68000: 2.969393
# Average loss at step 70000: 3.011198
# Nearest to can: could, will, should, must, may, might, cannot, would,
# Nearest to its: their, his, her, the, our, yearwood, platonist, hydrochloride,
# Nearest to eight: nine, six, seven, five, zero, three, two, furtherance,
# Nearest to time: times, period, least, thing, distance, looking, night, age,
# Nearest to if: when, where, though, because, ll, surpass, unless, whether,
# Nearest to when: if, before, though, where, while, although, after, because,
# Nearest to on: upon, fogo, around, about, under, policemen, at, across,
# Nearest to while: although, and, when, though, however, but, among, because,
# Nearest to state: government, lecter, decentralized, republic, territory, grievance, boii, himalayas,
# Nearest to of: amputee, including, almohades, for, in, harrisburg, throughout, gliding,
# Nearest to with: between, including, tougher, contended, boswell, heartbreak, unbreakable, by,
# Nearest to who: which, he, whose, satirist, workman, alem, already, dynamo,
# Nearest to not: still, never, indeed, conciliatory, shrinking, hort, now, legally,
# Nearest to by: had, when, via, exacted, newly, treviso, with, awry,
# Nearest to other: various, those, individual, some, older, others, sikhism, both,
# Nearest to states: kingdom, nations, coordinating, yorkist, mysterious, substitute, griswold, circling,
# Average loss at step 72000: 2.934123
# Average loss at step 74000: 2.866875
# Average loss at step 76000: 2.994242
# Average loss at step 78000: 3.003060
# Average loss at step 80000: 2.843893
# Nearest to can: may, could, cannot, should, might, must, will, would,
# Nearest to its: their, his, her, the, your, rhymed, platonist, our,
# Nearest to eight: nine, seven, six, five, four, three, zero, brahman,
# Nearest to time: thing, looking, night, least, distance, beginning, morning, end,
# Nearest to if: though, when, where, therefore, unless, circumcisions, since, perhaps,
# Nearest to when: if, before, where, though, although, until, after, because,
# Nearest to on: upon, in, toward, through, under, regarding, behind, augsburg,
# Nearest to while: although, though, where, however, among, but, nevertheless, when,
# Nearest to state: government, territory, copy, lecter, republic, slayton, observant, donate,
# Nearest to of: including, amputee, almohades, following, discernable, regarding, churchman, otomo,
# Nearest to with: between, heartbreak, xxxviii, requiring, emulates, containing, baines, unbreakable,
# Nearest to who: which, sorties, athenians, he, workman, washtenaw, alem, whom,
# Nearest to not: never, still, now, legally, already, condemned, cyclopedia, nothing,
# Nearest to by: without, kip, clearances, newly, through, crocodile, via, afield,
# Nearest to other: various, others, these, individual, chow, more, several, smaller,
# Nearest to states: kingdom, nations, provinces, countries, coordinating, emirates, yorkist, stockpiling,
# Average loss at step 82000: 2.936013
# Average loss at step 84000: 2.894202
# Average loss at step 86000: 2.921894
# Average loss at step 88000: 2.949846
# Average loss at step 90000: 2.839814
# Nearest to can: must, should, may, might, could, cannot, will, would,
# Nearest to its: their, his, the, your, whose, her, rhymed, hydrochloride,
# Nearest to eight: six, nine, five, four, three, zero, seven, adversus,
# Nearest to time: distance, period, least, point, thing, looking, year, night,
# Nearest to if: when, though, where, subcategories, therefore, since, currently, whatever,
# Nearest to when: if, where, until, although, while, though, since, because,
# Nearest to on: upon, through, in, amanda, against, across, otomo, fogo,
# Nearest to while: though, and, although, when, amongst, or, where, however,
# Nearest to state: government, moran, lecter, observant, cumberland, session, copy, annexes,
# Nearest to of: following, almohades, despite, including, amputee, discernable, regarding, otomo,
# Nearest to with: between, tuba, via, among, contended, terminus, containing, anoint,
# Nearest to who: benn, always, young, sorties, raps, whom, which, attenborough,
# Nearest to not: never, indeed, still, nothing, legally, almost, also, cyclopedia,
# Nearest to by: when, through, without, pelvic, in, sopranos, crocodile, actually,
# Nearest to other: others, various, textiles, different, both, roms, hae, fewer,
# Nearest to states: kingdom, nations, emirates, felt, coordinating, countries, yorkist, declared,
# Average loss at step 92000: 2.894091
# Average loss at step 94000: 2.882162
# Average loss at step 96000: 2.723037
# Average loss at step 98000: 2.457204
# Average loss at step 100000: 2.715885
# Nearest to can: could, must, should, cannot, might, may, will, would,
# Nearest to its: their, his, her, the, our, your, patrilineal, abductions,
# Nearest to eight: six, five, nine, seven, four, three, zero, th,
# Nearest to time: point, thing, period, night, distance, times, looking, stadium,
# Nearest to if: when, where, though, before, never, therefore, perhaps, anchoring,
# Nearest to when: if, where, although, because, though, also, until, that,
# Nearest to on: upon, in, around, toward, through, regarding, about, across,
# Nearest to while: and, although, however, though, where, when, believe, because,
# Nearest to state: government, session, states, lecter, observant, republic, mayoral, enciclopedia,
# Nearest to of: amputee, including, discernable, mailing, suk, churchman, otomo, harrisburg,
# Nearest to with: between, tuba, among, contended, without, precincts, ky, via,
# Nearest to who: which, whom, workman, and, young, hashshashin, avraham, transcended,
# Nearest to not: never, indeed, now, nothing, aaa, upheld, oscars, intracranial,
# Nearest to by: through, crocodile, ethicists, sopranos, collects, without, sturgis, gutrune,
# Nearest to other: others, earlier, different, various, older, previous, including, both,
# Nearest to states: kingdom, nations, emirates, state, coordinating, yorkist, griswold, manchester,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
